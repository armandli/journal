# %%
from torchvision import datasets
from torchvision.transforms import ToPILImage
from torchvision import transforms
from IPython.display import Image

# %%
data_dir = '/Users/armandli/data/'

# %%
to_img = ToPILImage()

# %%
dataset = datasets.MNIST(root=data_dir, download=True)
img, label = dataset[10]

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=28x28>

# %%
dataset = datasets.CIFAR100(root=data_dir, download=True)
# Out:
# Files already downloaded and verified

# %%
img, label = dataset[10]

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=32x32>

# %%
dataset = datasets.CIFAR100(root=data_dir, download=True, transform=transforms.ToTensor())
# Out:
# Files already downloaded and verified

# %%
img, label = dataset[10]

# %%
img.shape
# Out:
# torch.Size([3, 32, 32])

# %%
to_img(img)
# Out:
# <PIL.Image.Image image mode=RGB size=32x32>

# %%
dataset = datasets.CelebA(root=data_dir, download=True)
# Out:
# Files already downloaded and verified

# %%
img, label = dataset[10]

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=178x218>
